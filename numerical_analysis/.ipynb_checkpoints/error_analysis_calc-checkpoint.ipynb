# %%
f (x) = x3 + 2x + k
# Out:
#   Cell In[54], line 1
#     __tmp__=var("x"); f = symbolic_expression(x3 + 2x + k ).function(x)
#                                                    ^
# SyntaxError: invalid decimal literal

# %%
f(x,k) = x^3 + 2*x + k; F(x) = diff(f,x,3) ; F(x)
# Out:
# 6

# %%
f(1)
# Out:
# k + 3

# %%
p = plot(f(x, -200), (x, -5, 5))
p += plot(f(x, -100), (x, -5, 5))
p += plot(f(x, 0),  (x, -5, 5))
p += plot(f(x, 100),  (x, -5, 5))
p += plot(f(x, 200),  (x, -5, 5))
p
# Out:
# Graphics object consisting of 5 graphics primitives

# %%
plot(F(x,1), (x, -2, 2))
# Out:
# Graphics object consisting of 1 graphics primitive
