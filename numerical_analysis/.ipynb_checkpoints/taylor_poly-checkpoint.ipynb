# %%
f (x) = x3 + 2x
# Out:
#   Cell In[1], line 1
#     __tmp__=var("x"); f = symbolic_expression(x3 + 2x).function(x)
#                                                    ^
# SyntaxError: invalid decimal literal

# %%
f(x) = cos(x); f(x)
# Out:
# cos(x)

# %%
P2(z) = f(z) + diff(f,z,1)*(x-z) + (diff(f,z,2)*(x-z)^2)/2 ; P2(z)
# Out:
# cos(z)

# %%
z = 0; P(x) = f(z) + diff(f,x,1).subs(x=z)*(x-z) + diff(f,x,2).subs(x=z)*(x-z)^2/2 ; P
# Out:
# x |--> -1/2*x^2 + 1
