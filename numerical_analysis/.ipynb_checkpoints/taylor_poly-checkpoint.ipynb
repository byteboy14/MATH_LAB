# %%
f(x) = x^3; f(x)
# Out:
# x^3

# %%
z = 0; P(x) = f(z) + diff(f,x,1).subs(x=z)*(x-z) + diff(f,x,2).subs(x=z)*(x-z)^2/2 ; P
# Out:
# x |--> 0

# %%
taylor(f,x,0,2)
# Out:
# x |--> 0

# %%
(1/24).n()
# Out:
# 0.0416666666666667

# %%
R(x) = diff(f,z,3).subs(x=z)*(x-z)^3/6 ; R
# Out:
# x |--> x^3

# %%
R(0.5)
# Out:
# 0.125000000000000

# %%
E(x) = f(x) - P(x); E
# Out:
# x |--> x^3

# %%
E(0.5)
# Out:
# 0.125000000000000
