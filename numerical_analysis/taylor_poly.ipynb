# %%
f(x) = x^3; f(x) ; z = 1 ; xi = function('xi') ;

# %%
P(x) = f(z) + diff(f,x,1).subs(x=z)*(x-z) + diff(f,x,2).subs(x=z)*(x-z)^2/2 ; P
# Out:
# x |--> 3*(x - 1)^2 + 3*x - 2

# %%
taylor(f,x,z,2)
# Out:
# x |--> 3*(x - 1)^2 + 3*x - 2

# %%
R(x) = diff(f,x,3).subs(x=xi(x))*(x-z)^3/6 ; R
# Out:
# x |--> (x - 1)^3

# %%
R(0.5)
# Out:
# -0.125000000000000

# %%
E(x) = f(x) - P(x); E
# Out:
# x |--> x^3 - 3*(x - 1)^2 - 3*x + 2

# %%
E(0.5)
# Out:
# -0.125000000000000

# %%
E(0.5) == R(0.5)
# Out:
# -0.125000000000000 == -0.125000000000000

# %%
f(0.5) == P(0.5)
# Out:
# 0.125000000000000 == 0.250000000000000
