# %%
 x − 3−x = 0

# %%
f(x) = x - 3^-x

# %%
f(0.5).n()
# Out:
# -0.0773502691896258

# %%
e.n()
# Out:
# 2.71828182845905

# %%
plot(f(x), (x, 0.5, 0.6))
# Out:
# Graphics object consisting of 1 graphics primitive
